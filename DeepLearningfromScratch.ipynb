# %%
### DeepLearningfromScratch
type(18.0)
# Out:
# float

# %%
x=18
type(x)
# Out:
# int

# %%
x=18
type(x+0.0)
# Out:
# float

# %%
y = [1,3,5,7,9]
len(y)
y[3]
y
y[3] = int(y[4])+10
y[0:4]  #index 4 is not included
# Out:
# [1, 3, 5, 19]

# %%
me = {'name':'ijaegu', 'age': 30, 'hobby': ['coding', 'cooking']}
me['name']
# Out:
# 'ijaegu'
